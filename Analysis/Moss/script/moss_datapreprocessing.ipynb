# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
###### the original dataset without datacleaning

PATH = '../data/rawdata/'
FILES = ['Processed_all species in family level.xlsx', 'Moss-classification.xlsx']

# %%
abundance_df = pd.read_excel(PATH+FILES[0])

# %%
# Generate new column names
new_column_names = [f"family{i//2 + 1}" if i % 2 == 0 else f"abundance{i//2 + 1}" for i in range(34)]

# Rename the columns
abundance_df.columns = new_column_names

# %%
abundance_df.head()
# Out:
#                      family1  abundance1                         family2  \
# 0           Beijerinckiaceae   45.833333  Bryum argenteum var. argenteum
# 1           Mycobacteriaceae   25.000000             Chloroplast (Order)
# 2  Obscuribacterales (Order)   20.833333             Chloroplast (Order)
# 3         Ktedonobacteraceae    8.333333                     Opitutaceae
# 4           Chitinophagaceae    0.000000                     Nostocaceae
#
#    abundance2             family3  abundance3             family4  abundance4  \
# 0    8.810919       Kosmotogaceae   36.363636   Xanthobacteraceae    1.198424
# 1    5.933329   Dysgonomonadaceae   27.272727         Devosiaceae    1.186403
# 2    1.775470     Spirochaetaceae   18.181818      Micropepsaceae    0.736994
# 3    1.754333  Prolixibacteraceae   18.181818  Rhodanobacteraceae    0.678737
# 4    1.672806    Chitinophagaceae    0.000000      Micropepsaceae    0.650071
#
#              family5  abundance5  ...                        family13  \
# 0  Gemmatimonadaceae    4.289914  ...  Bryum argenteum var. argenteum
# 1   Pseudomonadaceae    2.729285  ...  Bryum argenteum var. argenteum
# 2        Devosiaceae    1.665880  ...                 Spirochaetaceae
# 3   Burkholderiaceae    1.361013  ...             Chloroplast (Order)
# 4        Opitutaceae    1.183174  ...                Xanthomonadaceae
#
#    abundance13          family14  abundance14                      family15  \
# 0     5.457327   Spirochaetaceae    10.051650            Ktedonobacteraceae
# 1     3.978239  Xanthomonadaceae     7.764288  Solibacteraceae (Subgroup 3)
# 2     3.095731  Mycobacteriaceae     3.994500                Ambiguous_taxa
# 3     2.870081  Burkholderiaceae     3.863697                   Gimesiaceae
# 4     1.859293  Beijerinckiaceae     3.602093      Acidobacteriales (Order)
#
#    abundance15                   family16  abundance16          family17  \
# 0     8.366511           Mycobacteriaceae    22.903226  Beijerinckiaceae
# 1     2.724834           Beijerinckiaceae    18.709677  Mycobacteriaceae
# 2     2.710716            Spirochaetaceae    13.870968  Burkholderiaceae
# 3     1.993506           Pseudomonadaceae     8.387097  Burkholderiaceae
# 4     1.629253  Obscuribacterales (Order)     6.129032   Spirochaetaceae
#
#    abundance17
# 0    23.868313
# 1    14.814815
# 2    11.934156
# 3     6.995885
# 4     6.584362
#
# [5 rows x 34 columns]

# %%
abundance_df.shape
# Out:
# (6719, 34)

# %%
# Combine dataframes into a list, each list is a sample
abundance_dflist = []
for i in range(1, 18):  # Iterating through each pair
    temp_df = pd.DataFrame({"abundance": abundance_df[f"abundance{i}"].values}, index=abundance_df[f"family{i}"])
    # Drop rows with missing or zero values
    temp_df_cleaned = temp_df[(temp_df[f"abundance"] != 0) & (~temp_df[f"abundance"].isna())]
    # Combine rows by summing values for the same index
    temp_df_final = temp_df_cleaned.groupby(temp_df_cleaned.index).sum()
    temp_df_final = temp_df_final.sort_values(by='abundance', ascending=False)  
    abundance_dflist.append(temp_df_final)

# %%
# delete non-family abundance and calculate the remaining to relative abundance
relative_abundance_dflist = []
for i in range(17):
    df = abundance_dflist[i]
    df_family = df[~df.index.str.contains('Order|Phylum|Class')].copy()
    df_family['abundance'] =  df_family['abundance'] /df_family['abundance'].sum()*100
    relative_abundance_dflist.append(df_family)

# %%
print(abundance_dflist[0].iloc[:20,])
print(relative_abundance_dflist[0].iloc[:20,])
for i in range(17):
    print(relative_abundance_dflist[i].shape[0])
# Out:
#                            abundance
# family1
# Beijerinckiaceae           45.833333
# Mycobacteriaceae           25.000000
# Obscuribacterales (Order)  20.833333
# Ktedonobacteraceae          8.333333
#                     abundance
# family1
# Beijerinckiaceae    57.894737
# Mycobacteriaceae    31.578947
# Ktedonobacteraceae  10.526316
# 3
# 149
# 4
# 172
# 140
# 65
# 133
# 135
# 143
# 10
# 173
# 141
# 221
# 188
# 84
# 17
# 23

# %%
# combine the abundance from each sample to a dataframe 
relative_abundance_dft = pd.concat(relative_abundance_dflist, axis=1).fillna(0)

relative_abundance_df = relative_abundance_dft.T
relative_abundance_df.index = [f'Sp{i+1}' for i in range(len(relative_abundance_df))]

# %%
#
print(relative_abundance_df)
# Out:
#       Beijerinckiaceae  Mycobacteriaceae  Ktedonobacteraceae  \
# Sp1          57.894737         31.578947           10.526316
# Sp2           1.448965          0.631692            0.039258
# Sp3           0.000000          0.000000            0.000000
# Sp4           1.247068          0.856460            0.017705
# Sp5           0.524455          1.700505            0.190711
# Sp6           5.468805         80.751917            0.000000
# Sp7           2.525957          1.713743            0.005582
# Sp8           2.184587          1.202563            1.198402
# Sp9           1.280438          0.458262            0.705364
# Sp10          7.142857          7.142857            4.545455
# Sp11          0.997030          0.735948            0.068108
# Sp12          0.683286          1.895930            0.198979
# Sp13          4.018762          2.288878            0.075826
# Sp14          4.194349          4.617800            0.040155
# Sp15          1.897887          2.090615           10.224414
# Sp16         20.714286         25.357143            0.000000
# Sp17         24.786325         15.384615            0.000000
#
#       Bryum argenteum var. argenteum  Burkholderiaceae  Micromonosporaceae  \
# Sp1                         0.000000          0.000000            0.000000
# Sp2                        10.413990          6.381156            4.043540
# Sp3                         0.000000          0.000000            0.000000
# Sp4                         0.000000          4.564467            1.226043
# Sp5                         0.131114          8.470738            2.789145
# Sp6                         0.000000          5.992825            0.000000
# Sp7                         0.018142          4.873283            0.117227
# Sp8                         0.000000         17.023136            0.000000
# Sp9                         0.000000         10.149160            4.834217
# Sp10                        0.000000          0.000000            0.000000
# Sp11                        9.724351          3.942713            1.772707
# Sp12                        0.000000          3.525304            6.284727
# Sp13                       10.765487          4.905747            0.617186
# Sp14                        0.135066         10.947653            0.032854
# Sp15                        0.000000          3.952569            0.133930
# Sp16                        0.000000          5.000000            0.000000
# Sp17                        0.000000         19.658120            0.000000
#
#       Opitutaceae  WD2101 soil group  Xanthobacteraceae  Chitinophagaceae  \
# Sp1      0.000000           0.000000           0.000000          0.000000
# Sp2      4.025696           3.540328           3.404711          3.222698
# Sp3      0.000000           0.000000           0.000000          0.000000
# Sp4      1.406409           3.713540           6.305050          6.754304
# Sp5      3.198379           5.602130           3.929437          3.579801
# Sp6      0.014068           0.000000           0.274319          0.235633
# Sp7      1.646757           6.127889           2.756224          1.773752
# Sp8      0.890479           4.277630           5.629993          3.649301
# Sp9      2.920298           4.506245           3.149429          3.037110
# Sp10     0.000000           0.000000           0.000000          5.844156
# Sp11     2.166222           2.079195           4.222714          5.223528
# Sp12     0.551885           2.800721           5.984382          2.402763
# Sp13     0.357968           2.331200           1.144439          1.518278
# Sp14     0.178871           1.062276           0.741038          0.996569
# Sp15     1.215170           7.830007           4.200830          0.852579
# Sp16     0.000000           0.000000           0.000000          0.000000
# Sp17     0.000000           0.000000           0.000000          2.350427
#
#       ...  Marinifilaceae  Aerococcaceae  Acetobacterales Incertae Sedis  \
# Sp1   ...        0.000000       0.000000                        0.000000
# Sp2   ...        0.000000       0.000000                        0.000000
# Sp3   ...        0.000000       0.000000                        0.000000
# Sp4   ...        0.000000       0.000000                        0.000000
# Sp5   ...        0.000000       0.000000                        0.000000
# Sp6   ...        0.000000       0.000000                        0.000000
# Sp7   ...        0.000000       0.000000                        0.000000
# Sp8   ...        0.000000       0.000000                        0.000000
# Sp9   ...        0.000000       0.000000                        0.000000
# Sp10  ...        0.000000       0.000000                        0.000000
# Sp11  ...        0.000000       0.000000                        0.000000
# Sp12  ...        0.000000       0.000000                        0.000000
# Sp13  ...        0.000000       0.000000                        0.000000
# Sp14  ...        0.054757       0.032854                        0.032854
# Sp15  ...        0.000000       0.000000                        0.000000
# Sp16  ...        0.000000       0.000000                        0.000000
# Sp17  ...        0.000000       0.000000                        0.000000
#
#       Bacteroidaceae  Hydrogenophilaceae  Arachis hypogaea var. vulgaris  \
# Sp1         0.000000            0.000000                        0.000000
# Sp2         0.000000            0.000000                        0.000000
# Sp3         0.000000            0.000000                        0.000000
# Sp4         0.000000            0.000000                        0.000000
# Sp5         0.000000            0.000000                        0.000000
# Sp6         0.000000            0.000000                        0.000000
# Sp7         0.000000            0.000000                        0.000000
# Sp8         0.000000            0.000000                        0.000000
# Sp9         0.000000            0.000000                        0.000000
# Sp10        0.000000            0.000000                        0.000000
# Sp11        0.000000            0.000000                        0.000000
# Sp12        0.000000            0.000000                        0.000000
# Sp13        0.000000            0.000000                        0.000000
# Sp14        0.032854            0.032854                        0.029203
# Sp15        0.000000            0.000000                        0.000000
# Sp16        0.000000            0.000000                        0.000000
# Sp17        0.000000            0.000000                        0.000000
#
#       Demequinaceae  Pseudohongiellaceae  Bacteroidetes vadinHA17  \
# Sp1        0.000000             0.000000                 0.000000
# Sp2        0.000000             0.000000                 0.000000
# Sp3        0.000000             0.000000                 0.000000
# Sp4        0.000000             0.000000                 0.000000
# Sp5        0.000000             0.000000                 0.000000
# Sp6        0.000000             0.000000                 0.000000
# Sp7        0.000000             0.000000                 0.000000
# Sp8        0.000000             0.000000                 0.000000
# Sp9        0.000000             0.000000                 0.000000
# Sp10       0.000000             0.000000                 0.000000
# Sp11       0.000000             0.000000                 0.000000
# Sp12       0.000000             0.000000                 0.000000
# Sp13       0.000000             0.000000                 0.000000
# Sp14       0.029203             0.025553                 0.025553
# Sp15       0.000000             0.000000                 0.000000
# Sp16       0.000000             0.000000                 0.000000
# Sp17       0.000000             0.000000                 0.000000
#
#       Thermoanaerobacteraceae
# Sp1                  0.000000
# Sp2                  0.000000
# Sp3                  0.000000
# Sp4                  0.000000
# Sp5                  0.000000
# Sp6                  0.000000
# Sp7                  0.000000
# Sp8                  0.000000
# Sp9                  0.000000
# Sp10                 0.000000
# Sp11                 0.000000
# Sp12                 0.000000
# Sp13                 0.000000
# Sp14                 0.000000
# Sp15                 0.016333
# Sp16                 0.000000
# Sp17                 0.000000
#
# [17 rows x 328 columns]

# %%
relative_abundance_df.to_csv('../data/relative_abundance_df.csv', index=True)  # index=False to exclude index from the file
