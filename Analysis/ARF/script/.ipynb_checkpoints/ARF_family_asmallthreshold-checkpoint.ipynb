# %% [markdown]
# This is the analysis of ARF data:
# analysis of Family, add 'Depth' and 'Donor' as features in prediction model.
# Using 'Phase' as response variable which has 5 levels

# %%
import sys
sys.path.append('../../../Code')
import loadData 
import RunML
import FS
import metric
# Out:
# 2025-03-10 00:55:48.937012: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
import numpy as np
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
import pickle
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# ### Data preprocess

# %%
# target variable
metadata_bact= pd.read_csv('../data/ARF_16S_metadata.csv',index_col = 0)

# %%
metadata_bact
# Out:
#                      Sample Sample_name    Type Location      Depth  \
# SP_A0            con15_mean          A0   con15  control       core
# SP_A0_CONINT    conint_mean   A0_CONINT  conint  control  interface
# SP_A0_CORE1       gr_15_sp1    A0_CORE1    gr15    grave       core
# SP_A0_CORE2       gr_15_sp2    A0_CORE2    gr15    grave       core
# SP_A0_CORE3       gr_15_sp3    A0_CORE3    gr15    grave       core
# ...                     ...         ...     ...      ...        ...
# WIN_V384_CORE2   gr_15_win2  V384_CORE2    gr15    grave       core
# WIN_V384_CORE3   gr_15_win3  V384_CORE3    gr15    grave       core
# WIN_V384_IN1    gr_int_win1    V384_IN1   grint    grave  interface
# WIN_V384_IN2    gr_int_win2    V384_IN2   grint    grave  interface
# WIN_V384_IN3    gr_int_win3    V384_IN3   grint    grave  interface
#
#                 Study_day Sort1 Sort2              Stage             Stage1  \
# SP_A0                   0     A   con            Initial            Control
# SP_A0_CONINT            0     A   con            Initial            Control
# SP_A0_CORE1             0     A    DA            Initial          D_Initial
# SP_A0_CORE2             0     A    DA            Initial          D_Initial
# SP_A0_CORE3             0     A    DA            Initial          D_Initial
# ...                   ...   ...   ...                ...                ...
# WIN_V384_CORE2        384     V     V  Skeletonization10  H_Skeletonization
# WIN_V384_CORE3        384     V     V  Skeletonization10  H_Skeletonization
# WIN_V384_IN1          384     V     V  Skeletonization10  H_Skeletonization
# WIN_V384_IN2          384     V     V  Skeletonization10  H_Skeletonization
# WIN_V384_IN3          384     V     V  Skeletonization10  H_Skeletonization
#
#                 ...   CN_ratio    copies.gdw  log.copies.gdw  \
# SP_A0           ...  13.441867  4.455430e+09        9.648889
# SP_A0_CONINT    ...  15.469767  1.846670e+09        9.266390
# SP_A0_CORE1     ...  13.054900  5.649630e+09        9.752020
# SP_A0_CORE2     ...  13.353700  5.472100e+09        9.738154
# SP_A0_CORE3     ...  13.179500  3.839910e+09        9.584321
# ...             ...        ...           ...             ...
# WIN_V384_CORE2  ...  12.715000  2.729230e+10       10.436041
# WIN_V384_CORE3  ...  10.938100  2.768460e+10       10.442238
# WIN_V384_IN1    ...  11.135800  3.847180e+10       10.585143
# WIN_V384_IN2    ...  13.479300  5.061330e+10       10.704264
# WIN_V384_IN3    ...  10.428500  4.236170e+10       10.626974
#
#                 fungal.bacterial.ratio  log.f.b.ratio        Chao1   Shannon  \
# SP_A0                         0.018761      -1.726748  4519.472160  6.624858
# SP_A0_CONINT                  0.052861      -1.276864  4444.733485  6.462025
# SP_A0_CORE1                   0.018689      -1.728420  4506.556818  6.249346
# SP_A0_CORE2                   0.015939      -1.797540  5374.504970  6.304635
# SP_A0_CORE3                   0.039678      -1.401455  5235.051661  6.165267
# ...                                ...            ...          ...       ...
# WIN_V384_CORE2                0.113406      -0.945363  4574.817289  6.248682
# WIN_V384_CORE3                0.153057      -0.815146  2067.000000  5.805210
# WIN_V384_IN1                  0.213479      -0.670644  4288.837004  6.218457
# WIN_V384_IN2                  0.149665      -0.824881  4027.835411  6.153355
# WIN_V384_IN3                  0.101256      -0.994578  1568.290076  5.224084
#
#                 InvSimpson     Phase       Donor
# SP_A0           208.516238   Initial     Control
# SP_A0_CONINT    149.034180   Initial     Control
# SP_A0_CORE1     121.798808   Initial      Donor1
# SP_A0_CORE2     120.388345   Initial      Donor2
# SP_A0_CORE3     108.686395   Initial      Donor3
# ...                    ...       ...         ...
# WIN_V384_CORE2  103.826366  RECOVERY  Donor2_win
# WIN_V384_CORE3  118.902115  RECOVERY  Donor3_win
# WIN_V384_IN1    127.487665  RECOVERY  Donor1_win
# WIN_V384_IN2    137.919647  RECOVERY  Donor2_win
# WIN_V384_IN3     66.048554  RECOVERY  Donor3_win
#
# [312 rows x 29 columns]

# %%
y = metadata_bact['Phase'].values 
pd.Series(y).value_counts()
# Out:
# RECOVERY    136
# DECLINE      64
# BLOOM        48
# CLIMAX       48
# Initial      16
# Name: count, dtype: int64

# %%
cts_family_combine = pd.read_csv('../data/ARF_16S_ctb_Family.csv',index_col = 0)

# %%
cts_family_combine.shape
# Out:
# (312, 442)

# %%
# Reorder df1 based on df2's index
cts_family_combine = cts_family_combine.reindex(metadata_bact.index)
cts_family_combine
# Out:
#                 Xiphinematobacteraceae  Xanthobacteraceae  \
# SP_A0                       234.172682         443.550609
# SP_A0_CONINT                139.478198         346.212874
# SP_A0_CORE1                 459.284589         785.812464
# SP_A0_CORE2                 351.996220         773.551723
# SP_A0_CORE3                 392.253406         671.991539
# ...                                ...                ...
# WIN_V384_CORE2              299.807903         870.266191
# WIN_V384_CORE3              160.550459         452.981651
# WIN_V384_IN1                407.015004         741.642538
# WIN_V384_IN2                 37.829836         265.513757
# WIN_V384_IN3                 34.462270         180.629828
#
#                 Chthoniobacteraceae  Rhodanobacteraceae  Corynebacteriaceae  \
# SP_A0                    378.533253            8.815913            0.000000
# SP_A0_CONINT             262.706509           50.555204            0.000000
# SP_A0_CORE1              375.808777            5.028663            0.000000
# SP_A0_CORE2              561.724020            2.624879            0.787464
# SP_A0_CORE3              580.994584            0.911793            0.000000
# ...                             ...                 ...                 ...
# WIN_V384_CORE2           740.257958           15.436334            0.000000
# WIN_V384_CORE3           203.555046          632.167431           30.103211
# WIN_V384_IN1             531.718873           22.045275            3.290340
# WIN_V384_IN2             214.995653          157.663479            2.349679
# WIN_V384_IN3              59.417706          525.252525           23.767083
#
#                 Subgroup_6_fa  Burkholderiaceae  Mycobacteriaceae  \
# SP_A0             1032.012783        109.647914         76.588242
# SP_A0_CONINT       992.145888        352.080888         64.999549
# SP_A0_CORE1        836.434342         94.874116        142.814040
# SP_A0_CORE2        922.119852         93.708166         98.432947
# SP_A0_CORE3        855.626675         70.937506         69.843354
# ...                       ...               ...               ...
# WIN_V384_CORE2     763.927003        116.287047        155.735456
# WIN_V384_CORE3     409.977064        564.793578        153.383028
# WIN_V384_IN1       868.649645        147.407212        205.317189
# WIN_V384_IN2       172.466458        686.106346        218.755140
# WIN_V384_IN3        83.184789        761.734997        128.342246
#
#                 Enterococcaceae  Nocardiaceae  ...  \
# SP_A0                  0.000000      6.060940  ...
# SP_A0_CONINT           0.000000     22.117902  ...
# SP_A0_CORE1            0.335244     11.733548  ...
# SP_A0_CORE2            0.000000      4.724781  ...
# SP_A0_CORE3            0.182359      2.917738  ...
# ...                         ...           ...  ...
# WIN_V384_CORE2         0.000000     34.645993  ...
# WIN_V384_CORE3         5.733945     64.506881  ...
# WIN_V384_IN1           0.000000    123.716768  ...
# WIN_V384_IN2           0.000000    345.637820  ...
# WIN_V384_IN3           9.506833    108.140226  ...
#
#                 Gracilibacteria_unclassified  Armatimonadetes_unclassified  \
# SP_A0                               0.000000                      0.000000
# SP_A0_CONINT                        0.902772                      0.000000
# SP_A0_CORE1                         0.000000                      0.000000
# SP_A0_CORE2                         0.000000                      0.000000
# SP_A0_CORE3                         0.182359                      0.182359
# ...                                      ...                           ...
# WIN_V384_CORE2                      0.000000                      0.000000
# WIN_V384_CORE3                      0.000000                      0.000000
# WIN_V384_IN1                        0.000000                      0.000000
# WIN_V384_IN2                        0.000000                      0.000000
# WIN_V384_IN3                        0.000000                      0.000000
#
#                 Catenulisporaceae  27F-1492R  bac2nit3  \
# SP_A0                    0.550995   1.101989  0.000000
# SP_A0_CONINT             0.000000   0.000000  0.000000
# SP_A0_CORE1              0.000000   0.000000  0.000000
# SP_A0_CORE2              0.262488   0.000000  0.000000
# SP_A0_CORE3              0.000000   0.000000  0.000000
# ...                           ...        ...       ...
# WIN_V384_CORE2           0.000000   0.343030  0.686059
# WIN_V384_CORE3           0.000000   0.000000  1.433486
# WIN_V384_IN1             0.000000   0.000000  0.000000
# WIN_V384_IN2             0.000000   0.000000  0.234968
# WIN_V384_IN3             0.000000   0.000000  0.000000
#
#                 Candidatus_Azambacteria_fa  Clostridia_unclassified  \
# SP_A0                             1.101989                      0.0
# SP_A0_CONINT                      0.451386                      0.0
# SP_A0_CORE1                       0.000000                      0.0
# SP_A0_CORE2                       1.574927                      0.0
# SP_A0_CORE3                       0.182359                      0.0
# ...                                    ...                      ...
# WIN_V384_CORE2                    0.000000                      0.0
# WIN_V384_CORE3                    0.000000                      0.0
# WIN_V384_IN1                      0.000000                      0.0
# WIN_V384_IN2                      0.000000                      0.0
# WIN_V384_IN3                      0.000000                      0.0
#
#                 Bacilli_unclassified  Lineage_IIc_fa  Victivallaceae
# SP_A0                            0.0        0.550995             0.0
# SP_A0_CONINT                     0.0        0.000000             0.0
# SP_A0_CORE1                      0.0        0.000000             0.0
# SP_A0_CORE2                      0.0        0.524976             0.0
# SP_A0_CORE3                      0.0        0.182359             0.0
# ...                              ...             ...             ...
# WIN_V384_CORE2                   0.0        0.000000             0.0
# WIN_V384_CORE3                   0.0        0.000000             0.0
# WIN_V384_IN1                     0.0        0.000000             0.0
# WIN_V384_IN2                     0.0        0.000000             0.0
# WIN_V384_IN3                     0.0        0.000000             0.0
#
# [312 rows x 442 columns]

# %%
feature_names = cts_family_combine.columns

# %% [markdown]
# ##### 1. calculate H statistics for OTU/phylum/class/order (both 16s and ITS)

# %%
select_result = FS.SelectMicro_fun(cts_family_combine,y
                                  # ,threshold=0.001
                                  )

data = select_result['relative_abundance_data']
weights = select_result['H_score']
selectedOTU_index = select_result['selected_indices']
X_FS = select_result['selected_data']
selectedASVs = select_result['selected_columnames']

# %%
selectedASVs
# Out:
# Index(['Chitinophagaceae', 'Enterococcaceae', 'Rhodanobacteraceae',
#        'Corynebacteriaceae', 'Moraxellaceae', 'Wohlfahrtiimonadaceae',
#        'Xanthomonadaceae', 'Rhizobiaceae', 'Streptomycetaceae',
#        'Sphingomonadaceae', 'Enterobacteriaceae', 'IMCC26256_fa', 'Family_XI',
#        'Micromonosporaceae', 'Isosphaeraceae', 'Lactobacillaceae',
#        'JG30-KF-CM45', 'Microbacteriaceae', 'Burkholderiaceae', 'SC-I-84',
#        'Gaiellaceae', 'Dysgonomonadaceae', 'Sphingobacteriaceae',
#        'Nocardiaceae', 'Peptostreptococcaceae', 'Planococcaceae',
#        'Weeksellaceae', 'MB-A2-108_fa', 'KD4-96_fa', 'Beijerinckiaceae',
#        'Bacteroidaceae', 'uncultured', 'Brevibacteriaceae', '67-14',
#        'Devosiaceae', 'Caulobacteraceae', 'Thermomonosporaceae',
#        'Subgroup_6_fa', 'Micropepsaceae', 'Geminicoccaceae', 'Mitochondria',
#        'Mycobacteriaceae', 'Nitrosomonadaceae', 'Xanthobacteraceae',
#        'Intrasporangiaceae', 'Bacillaceae', 'Flavobacteriaceae',
#        'Nocardioidaceae', 'Chthoniobacteraceae', 'Micrococcaceae',
#        'Pseudomonadaceae', 'Gemmataceae', 'Actinomycetaceae', 'Prevotellaceae',
#        'Ruminococcaceae', 'Pseudonocardiaceae', 'Xiphinematobacteraceae',
#        'Lachnospiraceae', 'Dietziaceae', 'Clostridiaceae_1',
#        'Pyrinomonadaceae', 'Promicromonosporaceae', 'Bacilli_unclassified',
#        'Gemmatimonadaceae', 'Staphylococcaceae',
#        'Deltaproteobacteria_unclassified', 'Spirosomaceae', 'Leuconostocaceae',
#        'Crocinitomicaceae', 'uncultured.1', 'Roseiflexaceae', '11-24_fa',
#        'Bacillales_unclassified', 'Rhodocyclaceae', 'Rokubacteriales_fa',
#        'Veillonellaceae', 'Pedosphaeraceae', 'Holophagaceae',
#        'Micrococcales_unclassified', 'Rhizobiales_unclassified',
#        'Blastocatellaceae', 'Clostridiales_unclassified', 'Arcobacteraceae',
#        'Bacteria_unclassified'],
#       dtype='object')

# %%
data
# Out:
# array([[0.02344052, 0.0443991 , 0.03789091, ..., 0.        , 0.        ,
#         0.        ],
#        [0.01395916, 0.03464944, 0.02629201, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0459454 , 0.07861024, 0.03759474, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.04071758, 0.07419355, 0.05319289, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.0265776 , 0.0215208 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.01830223, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# #### 4. Model
# Prepare 4 datasets: full dataset, our selected dataset, Lasso selected  dataset(based on the target variable), randomly selected data (selected the same numer of variables as in our method)
#
# Use random forest and SVM as classifier, and will build both models for each response variable.
#
# For Lasso, the dataset will be determined by the response variable, so the lasso subset is different for the models for different response variables.
#
# For random selection, the  process will repeat iter=30 times to  find the mean accuracy and AUC
#
# SMOTE  is used (the data is not balanced, as we can see the performance is really bad especially for SVM model when not using SMOTE)

# %%
iter =30
cls = ["RF","SVM", "CatBoost","NB"]

# %%
custom_phaseorder = ['Initial', 'BLOOM', 'CLIMAX', 'DECLINE', 'RECOVERY']
custom_mapping = {category: i for i, category in enumerate(custom_phaseorder)}
y = [custom_mapping[category] for category in y]
y = np.array(y)

# %%
targetLabel=y

# %%
X_lasso_ft,xlabel_lasso_ft  = RunML.LassoFS_CV(data,targetLabel)

X_FS_lasso_ft,xlabel_FS_lasso_ft0  = RunML.LassoFS_CV(X_FS,targetLabel)
xlabel_FS_lasso_ft = selectedOTU_index[xlabel_FS_lasso_ft0]

data_subset = {"AllFeatures":data, 
           "SelectMicro": X_FS,
           "Lasso_finetune":X_lasso_ft,
           "FS_Lassofinetune":X_FS_lasso_ft
          }
# Out:
# Best alpha: 0.1
# Best alpha: 0.1

# %%
   for datatype, subset in data_subset.items():
        print(datatype,np.shape(subset))
# Out:
# AllFeatures (312, 442)
# SelectMicro (312, 84)
# Lasso_finetune (312, 22)
# FS_Lassofinetune (312, 21)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import auc, roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, RocCurveDisplay, confusion_matrix, ConfusionMatrixDisplay
import shap

# %%
# Out:
# Classes: ['BLOOM' 'CLIMAX' 'DECLINE' 'Initial' 'RECOVERY']

# %%
# Set up 5-fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=777)
sm = SMOTE(k_neighbors=5, random_state=777)

# %%
clf = RandomForestClassifier(n_jobs=5, random_state=777)

# performance reports
accuracy_results = list()
f1_results = list()
precision_results = list()
recall_results = list()

for train_index, test_index in kf.split(data, y):
        # Split the data
        X_train, X_test = data[train_index], data[test_index]
        y_train, y_test = y[train_index], y[test_index]

        X_train, y_train = sm.fit_resample(X_train, y_train)
     
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        y_prob = clf.predict_proba(X_test)[:, 1]
        
        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        # roc_auc = roc_auc_score(y_test, y_prob)
        # mcc = metric.mcc_score(y_test,y_pred)
        f_score = f1_score(y_test,y_pred,average='weighted')
        prec = precision_score(y_test, y_pred,average='weighted')
        rec = recall_score(y_test, y_pred,average='weighted')

        explainer = shap.TreeExplainer(clf)
        shap_values = explainer.shap_values(X_test)

        # store the result
        accuracy_results.append(accuracy)
        f1_results.append(f_score)
        precision_results.append(prec)
        recall_results.append(rec)

# summarize the estimated performance of the model
print('Accuracy: %.3f (%.3f), F1: %.3f (%.3f), Precision: %.3f (%.3f), Recall: %.3f (%.3f)' % (np.mean(accuracy_results), np.std(accuracy_results), np.mean(f1_results), np.std(f1_results), np.mean(precision_results), np.std(precision_results), np.mean(recall_results), np.std(recall_results)))
# Out:
# Accuracy: 0.628 (0.061), F1: 0.620 (0.063), Precision: 0.628 (0.064), Recall: 0.628 (0.061)

# %%
# performance reports
accuracy_results = list()
f1_results = list()
precision_results = list()
recall_results = list()

for train_index, test_index in kf.split(X_FS_lasso_ft, y):
        # Split the data
        X_train, X_test = X_FS_lasso_ft[train_index], X_FS_lasso_ft[test_index]
        y_train, y_test = y[train_index], y[test_index]

        X_train, y_train = sm.fit_resample(X_train, y_train)
     
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        y_prob = clf.predict_proba(X_test)[:, 1]
        
        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        # roc_auc = roc_auc_score(y_test, y_prob)
        # mcc = metric.mcc_score(y_test,y_pred)
        f_score = f1_score(y_test,y_pred,average='weighted')
        prec = precision_score(y_test, y_pred,average='weighted')
        rec = recall_score(y_test, y_pred,average='weighted')

        explainer = shap.TreeExplainer(clf)
        shap_values = explainer.shap_values(X_test)

        # store the result
        accuracy_results.append(accuracy)
        f1_results.append(f_score)
        precision_results.append(prec)
        recall_results.append(rec)

# summarize the estimated performance of the model
print('Accuracy: %.3f (%.3f), F1: %.3f (%.3f), Precision: %.3f (%.3f), Recall: %.3f (%.3f)' % (np.mean(accuracy_results), np.std(accuracy_results), np.mean(f1_results), np.std(f1_results), np.mean(precision_results), np.std(precision_results), np.mean(recall_results), np.std(recall_results)))
# Out:
# Accuracy: 0.606 (0.060), F1: 0.598 (0.056), Precision: 0.607 (0.047), Recall: 0.606 (0.060)

# %% [markdown]
# ### Model with location

# %%
accuracy_results
# Out:
# [0.5238095238095238,
#  0.6825396825396826,
#  0.6451612903225806,
#  0.5483870967741935,
#  0.6290322580645161]

# %%
f1_results
# Out:
# [0.5231720938487856,
#  0.6749701490902321,
#  0.6387075738694497,
#  0.5491039426523299,
#  0.6047775229863517]

# %%
# performance reports
accuracy_results = list()
f1_results = list()
precision_results = list()
recall_results = list()

for train_index, test_index in kf.split(X_lasso_ft, y):
        # Split the data
        X_train, X_test = X_lasso_ft[train_index], X_lasso_ft[test_index]
        y_train, y_test = y[train_index], y[test_index]

        X_train, y_train = sm.fit_resample(X_train, y_train)
     
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        y_prob = clf.predict_proba(X_test)[:, 1]
        
        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        # roc_auc = roc_auc_score(y_test, y_prob)
        # mcc = metric.mcc_score(y_test,y_pred)
        f_score = f1_score(y_test,y_pred,average='weighted')
        prec = precision_score(y_test, y_pred,average='weighted')
        rec = recall_score(y_test, y_pred,average='weighted')

        explainer = shap.TreeExplainer(clf)
        shap_values = explainer.shap_values(X_test)

        # store the result
        accuracy_results.append(accuracy)
        f1_results.append(f_score)
        precision_results.append(prec)
        recall_results.append(rec)

# summarize the estimated performance of the model
print('Accuracy: %.3f (%.3f), F1: %.3f (%.3f), Precision: %.3f (%.3f), Recall: %.3f (%.3f)' % (np.mean(accuracy_results), np.std(accuracy_results), np.mean(f1_results), np.std(f1_results), np.mean(precision_results), np.std(precision_results), np.mean(recall_results), np.std(recall_results)))
# Out:
# Accuracy: 0.622 (0.058), F1: 0.610 (0.053), Precision: 0.611 (0.052), Recall: 0.622 (0.058)
# /Users/menglinghe/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Model with donor
