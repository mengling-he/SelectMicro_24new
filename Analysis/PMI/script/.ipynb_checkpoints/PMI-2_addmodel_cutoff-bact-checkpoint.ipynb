# %% [markdown]
# First, load the data,in this notebook we are using the PMI data from the paper:"Environmental predictors impact microbialbased postmortem interval (PMI) estimation models within human decomposition soils". The preprocessed data includes OTU/phylum/class/order abundance matrices (includes or not include environmental factors)

# %%
import sys
sys.path.append('../../../Code')
import loadData 
import RunML
import RunML_continue
import FS
import metric
# Out:
# 2025-01-17 12:04:54.029247: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 12:04:54.032008: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-17 12:04:54.036560: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-17 12:04:54.047499: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737133494.067080 2798096 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737133494.072528 2798096 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 12:04:54.092901: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
import numpy as np
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
import pickle
import matplotlib.pyplot as plt
import glob
import os

# %%
PMIdata_path = '../data/count_table/'

# %% [markdown]
# ## No env model
# 16s (OTU/phylum/class/order) - no env
#
# ITS (OTU/phylum/class/order) - no env
#
# 16s+ITS (OTU/phylum/class/order) - no env (only use this data when calculating H)
# bact.ITS.n.class.env

# %% [markdown]
# ### Data preprocess

# %%
bact_ITS_noenv_files = glob.glob(PMIdata_path + 'bact.ITS.n.*.noenv.csv')

# %%
bact_ITS_noenv_files
# Out:
# ['../data/count_table/bact.ITS.n.otu.noenv.csv',
#  '../data/count_table/bact.ITS.n.class.noenv.csv',
#  '../data/count_table/bact.ITS.n.order.noenv.csv',
#  '../data/count_table/bact.ITS.n.phylum.noenv.csv']

# %%
# Read each CSV file into a list of dataframes
bact_ITS_noenv_df_list = [pd.read_csv(file) for file in bact_ITS_noenv_files]
taxlabels = ['OTU', 'class', 'order', 'phylum']

# %%
for df in bact_ITS_noenv_df_list:
    print(df.shape)
# Out:
# (78, 7415)
# (78, 178)
# (78, 412)
# (78, 52)

# %%
# target variable
y = bact_ITS_noenv_df_list[3].iloc[:, 0].values 

# Define the threshold
y_threshold = 2500

# Categorize the series based on the threshold
y = np.where(y > y_threshold, 'LONG', 'SHORT')

print(y)

print(list(y).count('LONG'))
print(list(y).count('SHORT'))
# Out:
# ['SHORT' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'SHORT' 'SHORT'
#  'SHORT' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG'
#  'LONG' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT'
#  'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT'
#  'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG'
#  'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT'
#  'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG' 'SHORT' 'SHORT'
#  'LONG' 'LONG' 'SHORT' 'SHORT' 'SHORT' 'SHORT' 'SHORT' 'SHORT' 'LONG'
#  'LONG' 'SHORT' 'SHORT' 'LONG' 'LONG']
# 35
# 43

# %%
bact_ITS_noenv_df_list[3]
# Out:
#     ADH_10_actual  Proteobacteria  Verrucomicrobia  Acidobacteria  \
# 0         0.00000     2405.899397       957.553453    1988.986693
# 1      1484.14700     3209.276660       757.215776    1727.647573
# 2      1989.56009     3829.070365       412.942989     821.982537
# 3      2973.68000     3194.403374       419.280034     848.987596
# 4      4027.69203     3694.823154       475.772750     833.851140
# ..            ...             ...              ...            ...
# 73     4447.32241     2456.386357       702.629879    1096.355563
# 74        0.00000     2919.908680      1004.519405    1906.070913
# 75     1477.74800     4411.744255       735.145847    1127.142509
# 76     2554.43400     2821.384741       962.492330    1377.965842
# 77     4536.41300     2756.755257       598.263330     755.701049
#
#     Actinobacteria   Firmicutes  Bacteroidetes  Chloroflexi  Rokubacteria  \
# 0      2524.409168    92.418396     311.448621   526.359155    123.316076
# 1      1840.003679   226.398320     680.881068   465.059244    117.874278
# 2      1300.667694   389.111454    2416.230098   276.938880     48.073960
# 3      1688.948376  1069.522046    1868.083981   287.613030     65.055328
# 4      1209.230357   465.538458    2514.224448   230.271574     60.065548
# ..             ...          ...            ...          ...           ...
# 73     2612.831828  1416.120207     209.098033   519.102019    161.669485
# 74      954.200252    28.421004    1003.432263   630.853096     87.437295
# 75     1262.559538   178.006467     886.381810   434.238431    128.985155
# 76     1773.368787   586.137247     543.055840   570.541010    179.740233
# 77     2031.293347  2164.733951     366.892304   511.845975     93.907784
#
#     Entotheonellaeota  ...  p__Mucoromycota  p__Glomeromycota  \
# 0           99.009901  ...        86.785175         35.007547
# 1           67.904168  ...        73.063061         27.939985
# 2           41.088855  ...        47.127278          1.701346
# 3           42.488288  ...       101.508764          6.989128
# 4           51.049624  ...       493.950429          9.984729
# ..                ...  ...              ...               ...
# 73          29.144499  ...       354.041916          2.352438
# 74          19.413254  ...        34.921758        286.446822
# 75          45.718458  ...        45.856084         11.620207
# 76          65.964410  ...        28.655093         12.131353
# 77          12.622760  ...         3.980188          0.442243
#
#     p__Monoblepharomycota  p__unclassified_Fungi  p__Zoopagomycota  \
# 0                0.209626             127.662251          0.000000
# 1                0.977899             144.030622          0.000000
# 2                1.701346              71.966926          0.000000
# 3                0.000000              64.122476          0.000000
# 4                0.587337              96.323270          0.000000
# ..                    ...                    ...               ...
# 73               0.106929              18.712575          0.855432
# 74               7.956856             438.069136          0.442048
# 75               0.624742              11.620207          2.623918
# 76               2.509935              24.262707          1.464129
# 77               0.663365               3.980188          0.000000
#
#     p__Kickxellomycota  p__Olpidiomycota  p__Aphelidiomycota  \
# 0            11.739058               0.0            1.886634
# 1             7.264396               0.0            4.610098
# 2             4.593634               0.0            4.933903
# 3            18.193921               0.0            1.996894
# 4            14.096088               0.0            1.468343
# ..                 ...               ...                 ...
# 73           10.585971               0.0            0.534645
# 74            0.884095               0.0            0.000000
# 75            0.749691               0.0            0.249897
# 76            1.464129               0.0            0.209161
# 77            1.326729               0.0            0.000000
#
#     p__Blastocladiomycota  p__Basidiobolomycota
# 0                4.611773              0.000000
# 1               15.366992              0.000000
# 2                0.510404              0.000000
# 3                0.000000              3.106279
# 4                1.468343              0.000000
# ..                    ...                   ...
# 73               0.000000              0.000000
# 74               0.000000              0.000000
# 75               0.124948              0.000000
# 76               0.000000              0.000000
# 77               0.000000              0.000000
#
# [78 rows x 52 columns]

# %%
df_list = []
col_names_4taxa=[]
for df in bact_ITS_noenv_df_list:
    data = df.drop(df.columns[0], axis=1)# delete the response column
    df_list.append(data)
    cols_name = df.columns
    col_names_4taxa.append(cols_name)

# %% [markdown]
# #### OTU

# %% [markdown]
# ##### 1. calculate H statistics for OTU/phylum/class/order (both 16s and ITS)

# %%
data_4taxa = []
weights_4taxa = []
selectedOTU_index_4tax = []
X_FS_4taxa = []
selectedASVs_4taxa = []
eps_4tax = []
for df in df_list:
    select_result = FS.SelectMicro_fun(df,y,threshold=0.001)
    data_4taxa.append(select_result['relative_abundance_data'])
    weights_4taxa.append(select_result['H_score'])
    selectedOTU_index_4tax.append(select_result['selected_indices'])
    X_FS_4taxa.append(select_result['selected_data'])
    selectedASVs_4taxa.append(select_result['selected_columnames'])
    eps = len(select_result['selected_indices'])
    eps_4tax.append(eps)

# %%
print(eps_4tax)
# Out:
# [241, 63, 110, 23]

# %%
for weight in weights_4taxa:
    print(len(weight))
# Out:
# 7414
# 177
# 411
# 51

# %%
max(weights_4taxa[3])
# Out:
# 35.19353979026891

# %%
len(selectedOTU_index_4tax)
# Out:
# 4

# %%
for i in range(4):
    print(f"Selected features in {taxlabels[i]} : {selectedASVs_4taxa[i]}")
# Out:
# Selected features in OTU : Index(['Otu00009', 'ITS00002', 'ITS00001', 'Otu00008', 'ITS00006', 'ITS00050',
#        'Otu00003', 'Otu00174', 'Otu00150', 'Otu00007',
#        ...
#        'Otu00116', 'Otu00359', 'ITS00115', 'ITS00159', 'ITS00213', 'Otu00067',
#        'Otu00146', 'ITS00025', 'Otu00165', 'Otu00070'],
#       dtype='object', length=241)
# Selected features in class : Index(['Clostridia', 'c__Dothideomycetes', 'c__Saccharomycetes',
#        'c__unclassified_Fungi', 'Bacilli', 'c__Agaricomycetes',
#        'c__Rhizophydiomycetes', 'k__Fungi_unclassified', 'Negativicutes',
#        'p__Ascomycota_unclassified', 'c__Glomeromycetes',
#        'c__unclassified_Rozellomycota', 'Subgroup_6',
#        'p__Chytridiomycota_unclassified', 'Deltaproteobacteria',
#        'Thermoanaerobaculia', 'Bacteria_unclassified', 'Nitrospira',
#        'c__Rozellomycotina_cls_Incertae_sedis', 'Subgroup_22',
#        'c__Orbiliomycetes', 'Subgroup_5', 'Blastocatellia_(Subgroup_4)',
#        'p__Basidiomycota_unclassified', 'Holophagae', 'Latescibacteria_cl',
#        'c__Laboulbeniomycetes', 'c__unclassified_Glomeromycota',
#        'Verrucomicrobiae', 'TK10', 'OM190', 'Phycisphaerae',
#        'Gemmatimonadetes', 'Fusobacteriia', 'Actinobacteria', 'Anaerolineae',
#        'c__Atractiellomycetes', 'Dehalococcoidia',
#        'c__unclassified_Chytridiomycota', 'Proteobacteria_unclassified',
#        'p__Glomeromycota_unclassified', 'c__Eurotiomycetes', 'JG30-KF-CM66',
#        'c__Tremellomycetes', 'Bacteroidia', 'Melainabacteria',
#        'c__Lobulomycetes', 'p__Mortierellomycota_unclassified',
#        'Acidobacteriia', 'Campylobacteria', 'c__Sanchytriomycetes',
#        'Subgroup_17', 'Parcubacteria', 'p__Rozellomycota_unclassified',
#        'Subgroup_11', 'Pla4_lineage', 'c__Cystobasidiomycetes',
#        'c__Paraglomeromycetes', 'c__Sordariomycetes', 'c__Pezizomycetes',
#        'c__Leotiomycetes', 'c__Mortierellomycetes', 'Ktedonobacteria'],
#       dtype='object')
# Selected features in order : Index(['Clostridiales', 'Lactobacillales', 'o__Pleosporales',
#        'o__Saccharomycetales', 'o__unclassified_Fungi', 'Bacteroidales',
#        'o__Rhizophydiales', 'k__Fungi_unclassified', 'Selenomonadales',
#        'p__Ascomycota_unclassified',
#        ...
#        'SBR1031', 'Pirellulales', 'o__Pezizales', 'Dongiales',
#        'o__Mortierellales', 'Gammaproteobacteria_Incertae_Sedis',
#        'Betaproteobacteriales', 'Parcubacteria_unclassified',
#        'o__Ophiostomatales', 'c__Microbotryomycetes_unclassified'],
#       dtype='object', length=110)
# Selected features in phylum : Index(['Firmicutes', 'p__unclassified_Fungi', 'p__Chytridiomycota',
#        'p__Glomeromycota', 'k__Fungi_unclassified', 'Acidobacteria',
#        'p__Rozellomycota', 'Bacteria_unclassified', 'Nitrospirae',
#        'Latescibacteria', 'p__Ascomycota', 'Verrucomicrobia',
#        'Gemmatimonadetes', 'Fusobacteria', 'Armatimonadetes', 'Cyanobacteria',
#        'Planctomycetes', 'Bacteroidetes', 'Patescibacteria',
#        'Epsilonbacteraeota', 'Elusimicrobia', 'p__Monoblepharomycota',
#        'p__Mortierellomycota'],
#       dtype='object')

# %% [markdown]
# ##### 2. Select indices of the features based on H statistics and form the subset based on the selected features.
# The default p value of the function is 10%, the resulted index is ranked by its H statistics descendingly.
#
# Use "indice_H_unisig" if there is only one response, use "indice_H_multisig" for multiple responses.

# %% [markdown]
# weights_4taxa,selectedOTU_index_4tax,col_names_4taxa,eps_4tax

# %%
#plot the h statistics and cutoff descendingly
#for i in range(len(weights_4taxa)):
    #FS.plotWeightedIndex(weights_4taxa[i],threshold=eps_4tax[i])

# %% [markdown]
# #### 4. Model
# Prepare 4 datasets: full dataset, our selected dataset, Lasso selected  dataset(based on the target variable), randomly selected data (selected the same numer of variables as in our method)
#
# Use random forest and SVM as classifier, and will build both models for each response variable.
#
# For Lasso, the dataset will be determined by the response variable, so the lasso subset is different for the models for different response variables.
#
# For random selection, the  process will repeat iter=30 times to  find the mean accuracy and AUC
#
# SMOTE  is used (the data is not balanced, as we can see the performance is really bad especially for SVM model when not using SMOTE)

# %%
iter =30
cls = ["RF","SVM", "CatBoost","NB"]

# %%
targetLabel=y

# %%
data_subset_4taxa = []
X_lasso_4taxa = []
X_lasso_ft_4taxa = []
xind_lasso_4taxa = []
xind_lasso_ft_4taxa = []
for i, data  in enumerate(data_4taxa):
    X_lasso,xind_lasso = RunML_continue.LassoFeatureSelection(data,targetLabel)
    X_lasso_ft,xind_lasso_ft = RunML_continue.LassoFS_CV(data,targetLabel)
    X_lasso_4taxa.append(X_lasso)
    X_lasso_ft_4taxa.append(X_lasso_ft)
    xind_lasso_4taxa.append(xind_lasso)
    xind_lasso_ft_4taxa.append(xind_lasso_ft)
    data_subset = {"AllFeatures":data, 
                "SelectMicro": X_FS_4taxa[i],
                "Lasso":X_lasso,
                "Lasso_finetune":X_lasso_ft
              }
    data_subset_4taxa.append(data_subset)
# Out:
# Best alpha: 0.1
# Best alpha: 0.05
# Best alpha: 0.05
# Best alpha: 0.05

# %%
for i, dataset  in enumerate(data_subset_4taxa):
    data_subset = dataset
    print(taxlabels[i])
    for datatype, subset in data_subset.items():
        print(np.shape(subset))
# Out:
# OTU
# (78, 7414)
# (78, 241)
# (78, 37)
# (78, 9)
# class
# (78, 177)
# (78, 63)
# (78, 19)
# (78, 19)
# order
# (78, 411)
# (78, 110)
# (78, 23)
# (78, 23)
# phylum
# (78, 51)
# (78, 23)
# (78, 8)
# (78, 8)

# %%
with open('../data/data_subset_4taxa_paperthreshold.pkl', 'wb') as file:
    pickle.dump(data_subset_4taxa, file)

# %%
X_FS_lasso_4taxa = []
selectedOTU_index_FS_lasso_4taxa = []
X_FS_lassoft_4taxa = []
selectedOTU_index_FS_lassoft_4taxa = []

data_FS_lasso_4taxa = []

for i, data  in enumerate(data_4taxa):
    print(taxlabels[i])
        
    X_FS = X_FS_4taxa[i]
    
    X_FS_lasso,xlabel_FS_lasso = RunML_continue.LassoFeatureSelection(X_FS,targetLabel)# this is depend on the target variable(do not update here)
    X_FS_lasso_4taxa.append(X_FS_lasso)
    selectedOTU_index_FS_lasso_4taxa.append(np.array(selectedOTU_index_4tax[i])[xlabel_FS_lasso])

    X_FS_lasso_ft,xlabel_FS_lasso_ft  = RunML_continue.LassoFS_CV(X_FS,targetLabel)
    X_FS_lassoft_4taxa.append(X_FS_lasso_ft)
    selectedOTU_index_FS_lassoft_4taxa.append(np.array(selectedOTU_index_4tax[i])[xlabel_FS_lasso_ft])
    
    
    data_subset = {"FS_Lasso":X_FS_lasso,
                "FS_Lassofinetune":X_FS_lasso_ft}

    data_FS_lasso_4taxa.append(data_subset)
    
    print(f'The shape of the FS_Lasso selected dataset is ',np.shape(X_FS_lasso))
    print(f'The shape of the FS_Lasso_finetune selected dataset is ',np.shape(X_FS_lasso_ft))
# Out:
# OTU
# Best alpha: 0.1
# The shape of the FS_Lasso selected dataset is  (78, 27)
# The shape of the FS_Lasso_finetune selected dataset is  (78, 9)
# class
# Best alpha: 0.05
# The shape of the FS_Lasso selected dataset is  (78, 18)
# The shape of the FS_Lasso_finetune selected dataset is  (78, 18)
# order
# Best alpha: 0.05
# The shape of the FS_Lasso selected dataset is  (78, 20)
# The shape of the FS_Lasso_finetune selected dataset is  (78, 20)
# phylum
# Best alpha: 0.05
# The shape of the FS_Lasso selected dataset is  (78, 8)
# The shape of the FS_Lasso_finetune selected dataset is  (78, 8)

# %%
with open('../data/data_FS_lasso_4taxa_paperthreshold.pkl', 'wb') as file:
    pickle.dump(data_FS_lasso_4taxa, file)

# %%
#with open('../data/data_AE_4taxa.pkl', 'wb') as file:
#    pickle.dump(data_AE_4taxa, file)

# %% [markdown]
# ### Fisher_discriminant_ratio
#
# The Fisher Discriminant Ratio is a measure used in statistics and machine learning to evaluate the separability between two or more classes. It is commonly used in Linear Discriminant Analysis (LDA) to reduce dimensionality while preserving as much of the class discriminatory information as possible.
#
# Fisher's Criterion / Fisher's Discriminant Ratio
# Fisher's discriminant ratio evaluates how well the classes can be separated based on the ratio of the between-class scatter matrix to the within-class scatter matrix.

# %%
for i in range(len(taxlabels)):
    print(f"Analysis of {taxlabels[i]}")
    for datatype, subset in data_subset_4taxa[i].items():
        print(f"f1 of {datatype} = {metric.fisher_discriminant_ratio(subset,targetLabel)}")
    for datatype, subset in data_FS_lasso_4taxa[i].items():
        print(f"f1 of {datatype} = {metric.fisher_discriminant_ratio(subset,targetLabel)}")
# Out:
# Analysis of OTU
# f1 of AllFeatures = 0.10879770622249998
# f1 of SelectMicro = 0.16351061385571758
# f1 of Lasso = 0.32946794643444816
# f1 of Lasso_finetune = 0.3707398471350195
# f1 of FS_Lasso = 0.3320012747636476
# f1 of FS_Lassofinetune = 0.37073984713501945
# Analysis of class
# f1 of AllFeatures = 0.23191860388585298
# f1 of SelectMicro = 0.26226386006184893
# f1 of Lasso = 0.36031706744382525
# f1 of Lasso_finetune = 0.36031706744382525
# f1 of FS_Lasso = 0.3822647073104087
# f1 of FS_Lassofinetune = 0.3822647073104087
# Analysis of order
# f1 of AllFeatures = 0.2329827605002032
# f1 of SelectMicro = 0.28494426853063337
# f1 of Lasso = 0.39269792983219537
# f1 of Lasso_finetune = 0.39269792983219537
# f1 of FS_Lasso = 0.4149941894809504
# f1 of FS_Lassofinetune = 0.4149941894809504
# Analysis of phylum
# f1 of AllFeatures = 0.15966478518480431
# f1 of SelectMicro = 0.2238553733847558
# f1 of Lasso = 0.30602841426599053
# f1 of Lasso_finetune = 0.30602841426599053
# f1 of FS_Lasso = 0.3060284142659905
# f1 of FS_Lassofinetune = 0.3060284142659905

# %% [markdown]
# ### compare the first 15 index by their present ratio

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

entries=15

for i, data_FS in enumerate(X_FS_4taxa):
    selectedASVs_15=selectedASVs_4taxa[i][:entries]
    print(selectedASVs_15)
    X_FS_15=data_FS[:,:entries]
    print(X_FS_15.shape)
    #df=pd.DataFrame(data=X_FS_15)
    FS.plotPresenseRatio(X_FS_15,targetLabel,selectedASVs_15,posLabel="LONG",posText="Long",negText="short")
    FS.OTUviolin(X_FS_15,targetLabel,selectedASVs_15,y_max=0.5)
# Out:
# Index(['Otu00009', 'ITS00002', 'ITS00001', 'Otu00008', 'ITS00006', 'ITS00050',
#        'Otu00003', 'Otu00174', 'Otu00150', 'Otu00007', 'Otu00012', 'Otu00036',
#        'Otu00049', 'Otu00037', 'Otu00040'],
#       dtype='object')
# (78, 15)
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#          OTU  presence_pos  presence_neg
# 0   Otu00009      0.028571      0.348837
# 1   ITS00002      0.828571      0.279070
# 2   ITS00001      0.800000      0.279070
# 3   Otu00008      0.200000      0.000000
# 4   ITS00006      0.228571      0.627907
# 5   ITS00050      0.000000      0.046512
# 6   Otu00003      0.085714      0.000000
# 7   Otu00174      0.000000      0.000000
# 8   Otu00150      0.000000      0.000000
# 9   Otu00007      0.057143      0.302326
# 10  Otu00012      0.000000      0.000000
# 11  Otu00036      0.028571      0.000000
# 12  Otu00049      0.000000      0.069767
# 13  Otu00037      0.028571      0.000000
# 14  Otu00040      0.000000      0.000000
# Index(['Clostridia', 'c__Dothideomycetes', 'c__Saccharomycetes',
#        'c__unclassified_Fungi', 'Bacilli', 'c__Agaricomycetes',
#        'c__Rhizophydiomycetes', 'k__Fungi_unclassified', 'Negativicutes',
#        'p__Ascomycota_unclassified', 'c__Glomeromycetes',
#        'c__unclassified_Rozellomycota', 'Subgroup_6',
#        'p__Chytridiomycota_unclassified', 'Deltaproteobacteria'],
#       dtype='object')
# (78, 15)
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                                 OTU  presence_pos  presence_neg
# 0                        Clostridia      0.600000      0.139535
# 1                c__Dothideomycetes      0.142857      0.720930
# 2                c__Saccharomycetes      0.885714      0.488372
# 3             c__unclassified_Fungi      0.000000      0.348837
# 4                           Bacilli      0.685714      0.279070
# 5                 c__Agaricomycetes      0.257143      0.790698
# 6             c__Rhizophydiomycetes      0.000000      0.093023
# 7             k__Fungi_unclassified      0.685714      0.953488
# 8                     Negativicutes      0.114286      0.000000
# 9        p__Ascomycota_unclassified      0.000000      0.046512
# 10                c__Glomeromycetes      0.000000      0.093023
# 11    c__unclassified_Rozellomycota      0.028571      0.232558
# 12                       Subgroup_6      0.885714      0.976744
# 13  p__Chytridiomycota_unclassified      0.000000      0.069767
# 14              Deltaproteobacteria      0.914286      0.976744
# Index(['Clostridiales', 'Lactobacillales', 'o__Pleosporales',
#        'o__Saccharomycetales', 'o__unclassified_Fungi', 'Bacteroidales',
#        'o__Rhizophydiales', 'k__Fungi_unclassified', 'Selenomonadales',
#        'p__Ascomycota_unclassified', 'Bacilli_unclassified', 'o__Agaricales',
#        'o__unclassified_Rozellomycota', 'Bacillales', 'Pedosphaerales'],
#       dtype='object')
# (78, 15)
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                               OTU  presence_pos  presence_neg
# 0                   Clostridiales      0.600000      0.139535
# 1                 Lactobacillales      0.228571      0.046512
# 2                 o__Pleosporales      0.085714      0.441860
# 3            o__Saccharomycetales      0.885714      0.488372
# 4           o__unclassified_Fungi      0.000000      0.348837
# 5                   Bacteroidales      0.114286      0.000000
# 6               o__Rhizophydiales      0.000000      0.093023
# 7           k__Fungi_unclassified      0.685714      0.953488
# 8                 Selenomonadales      0.114286      0.000000
# 9      p__Ascomycota_unclassified      0.000000      0.046512
# 10           Bacilli_unclassified      0.200000      0.000000
# 11                  o__Agaricales      0.142857      0.395349
# 12  o__unclassified_Rozellomycota      0.028571      0.232558
# 13                     Bacillales      0.514286      0.209302
# 14                 Pedosphaerales      0.000000      0.418605
# Index(['Firmicutes', 'p__unclassified_Fungi', 'p__Chytridiomycota',
#        'p__Glomeromycota', 'k__Fungi_unclassified', 'Acidobacteria',
#        'p__Rozellomycota', 'Bacteria_unclassified', 'Nitrospirae',
#        'Latescibacteria', 'p__Ascomycota', 'Verrucomicrobia',
#        'Gemmatimonadetes', 'Fusobacteria', 'Armatimonadetes'],
#       dtype='object')
# (78, 15)
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                       OTU  presence_pos  presence_neg
# 0              Firmicutes      0.942857      0.418605
# 1   p__unclassified_Fungi      0.000000      0.348837
# 2      p__Chytridiomycota      0.000000      0.325581
# 3        p__Glomeromycota      0.000000      0.162791
# 4   k__Fungi_unclassified      0.685714      0.953488
# 5           Acidobacteria      0.971429      1.000000
# 6        p__Rozellomycota      0.171429      0.767442
# 7   Bacteria_unclassified      0.000000      0.023256
# 8             Nitrospirae      0.000000      0.000000
# 9         Latescibacteria      0.000000      0.046512
# 10          p__Ascomycota      1.000000      1.000000
# 11        Verrucomicrobia      0.914286      0.976744
# 12       Gemmatimonadetes      0.057143      0.232558
# 13           Fusobacteria      0.028571      0.000000
# 14        Armatimonadetes      0.000000      0.000000

# %%
for i, data_FS in enumerate(X_lasso_ft_4taxa):
    selectedASVs_15=col_names_4taxa[i][xind_lasso_ft_4taxa[i]]
    print(f"Fine tuned Lasso selected {selectedASVs_15}")
    X_FS_15=data_4taxa[i][:,xind_lasso_ft_4taxa[i]]
    #df=pd.DataFrame(data=X_FS_15)
    FS.plotPresenseRatio(X_FS_15,targetLabel,selectedASVs_15,posLabel="LONG",posText="Long",negText="short")
    FS.OTUviolin(X_FS_15,targetLabel,selectedASVs_15,y_max=0.5)
# Out:
# Fine tuned Lasso selected Index(['Otu00007', 'Otu00008', 'Otu00036', 'Otu00076', 'Otu00135', 'Otu00173',
#        'ITS00001', 'ITS00005', 'ITS00007'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#         OTU  presence_pos  presence_neg
# 0  Otu00007      0.200000      0.000000
# 1  Otu00008      0.028571      0.348837
# 2  Otu00036      0.028571      0.000000
# 3  Otu00076      0.000000      0.000000
# 4  Otu00135      0.000000      0.000000
# 5  Otu00173      0.000000      0.000000
# 6  ITS00001      0.828571      0.279070
# 7  ITS00005      0.228571      0.627907
# 8  ITS00007      0.400000      0.116279
# Fine tuned Lasso selected Index(['Gammaproteobacteria', 'Clostridia', 'Deltaproteobacteria',
#        'Thermoleophilia', 'Holophagae', 'Pla4_lineage', 'Lineage_IIc',
#        'c__Sordariomycetes', 'c__Eurotiomycetes', 'c__Mortierellomycetes',
#        'p__Rozellomycota_unclassified', 'c__Rhizophydiomycetes',
#        'c__unclassified_Rozellomycota', 'c__Mucoromycetes',
#        'c__unclassified_Mortierellomycota', 'c__Sanchytriomycetes',
#        'c__unclassified_Fungi', 'c__Archaeorhizomycetes', 'c__Orbiliomycetes'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                                   OTU  presence_pos  presence_neg
# 0                 Gammaproteobacteria      0.600000      0.139535
# 1                          Clostridia      1.000000      1.000000
# 2                 Deltaproteobacteria      0.685714      0.279070
# 3                     Thermoleophilia      0.114286      0.000000
# 4                          Holophagae      0.028571      0.000000
# 5                        Pla4_lineage      0.000000      0.000000
# 6                         Lineage_IIc      0.885714      0.488372
# 7                  c__Sordariomycetes      0.771429      0.604651
# 8                   c__Eurotiomycetes      0.771429      0.813953
# 9               c__Mortierellomycetes      0.685714      0.953488
# 10      p__Rozellomycota_unclassified      0.057143      0.348837
# 11              c__Rhizophydiomycetes      0.028571      0.232558
# 12      c__unclassified_Rozellomycota      0.142857      0.720930
# 13                   c__Mucoromycetes      0.057143      0.023256
# 14  c__unclassified_Mortierellomycota      0.000000      0.000000
# 15               c__Sanchytriomycetes      0.000000      0.348837
# 16              c__unclassified_Fungi      0.057143      0.000000
# 17             c__Archaeorhizomycetes      0.000000      0.000000
# 18                  c__Orbiliomycetes      0.000000      0.046512
# Fine tuned Lasso selected Index(['Pseudomonadales', 'Subgroup_6_or', 'Bacilli_unclassified',
#        'Solirubrobacterales', 'IMCC26256', 'Subgroup_5_or', 'Subgroup_7',
#        'S085', 'Pla4_lineage_or', 'Candidatus_Magasanikbacteria',
#        'o__Eurotiales', 'o__Mortierellales', 'o__Agaricales',
#        'o__unclassified_Rozellomycota', 'o__Mucorales',
#        'p__Chytridiomycota_unclassified', 'o__Leucosporidiales',
#        'o__Pleosporales', 'o__Pyxidiophorales', 'o__Sanchytriales',
#        'o__unclassified_Fungi', 'o__Ophiostomatales', 'o__Glomerales'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                                 OTU  presence_pos  presence_neg
# 0                   Pseudomonadales      0.600000      0.139535
# 1                     Subgroup_6_or      0.200000      0.000000
# 2              Bacilli_unclassified      0.428571      0.162791
# 3               Solirubrobacterales      0.114286      0.000000
# 4                         IMCC26256      0.000000      0.000000
# 5                     Subgroup_5_or      0.114286      0.000000
# 6                        Subgroup_7      0.028571      0.000000
# 7                              S085      0.000000      0.000000
# 8                   Pla4_lineage_or      0.000000      0.000000
# 9      Candidatus_Magasanikbacteria      0.885714      0.488372
# 10                    o__Eurotiales      0.771429      0.813953
# 11                o__Mortierellales      0.685714      0.953488
# 12                    o__Agaricales      0.028571      0.232558
# 13    o__unclassified_Rozellomycota      0.000000      0.023256
# 14                     o__Mucorales      0.057143      0.023256
# 15  p__Chytridiomycota_unclassified      0.028571      0.000000
# 16              o__Leucosporidiales      0.085714      0.441860
# 17                  o__Pleosporales      0.000000      0.093023
# 18               o__Pyxidiophorales      0.000000      0.000000
# 19                 o__Sanchytriales      0.000000      0.348837
# 20            o__unclassified_Fungi      0.057143      0.000000
# 21               o__Ophiostomatales      0.000000      0.000000
# 22                    o__Glomerales      0.000000      0.046512
# Fine tuned Lasso selected Index(['Verrucomicrobia', 'Actinobacteria', 'Entotheonellaeota', 'Nitrospirae',
#        'p__Basidiomycota', 'k__Fungi_unclassified', 'p__Rozellomycota',
#        'p__Monoblepharomycota'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                      OTU  presence_pos  presence_neg
# 0        Verrucomicrobia      0.971429      1.000000
# 1         Actinobacteria      0.942857      0.418605
# 2      Entotheonellaeota      0.000000      0.000000
# 3            Nitrospirae      0.028571      0.000000
# 4       p__Basidiomycota      0.828571      0.813953
# 5  k__Fungi_unclassified      0.171429      0.767442
# 6       p__Rozellomycota      0.000000      0.325581
# 7  p__Monoblepharomycota      0.000000      0.348837

# %%
for i, data_FS in enumerate(X_FS_lassoft_4taxa):
    selectedASVs_15=col_names_4taxa[i][selectedOTU_index_FS_lassoft_4taxa[i]]
    print(f"FS_Fine tuned Lasso selected {selectedASVs_15}")
    X_FS_15=data_4taxa[i][:,selectedOTU_index_FS_lassoft_4taxa[i]]
    #df=pd.DataFrame(data=X_FS_15)
    FS.plotPresenseRatio(X_FS_15,targetLabel,selectedASVs_15,posLabel="LONG",posText="Long",negText="short")
# Out:
# FS_Fine tuned Lasso selected Index(['Otu00008', 'ITS00001', 'Otu00007', 'ITS00005', 'Otu00173', 'Otu00036',
#        'Otu00135', 'Otu00076', 'ITS00007'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#         OTU  presence_pos  presence_neg
# 0  Otu00008      0.028571      0.348837
# 1  ITS00001      0.828571      0.279070
# 2  Otu00007      0.200000      0.000000
# 3  ITS00005      0.228571      0.627907
# 4  Otu00173      0.000000      0.000000
# 5  Otu00036      0.028571      0.000000
# 6  Otu00135      0.000000      0.000000
# 7  Otu00076      0.000000      0.000000
# 8  ITS00007      0.400000      0.116279
# FS_Fine tuned Lasso selected Index(['Gammaproteobacteria', 'c__unclassified_Rozellomycota', 'Lineage_IIc',
#        'c__Sanchytriomycetes', 'Deltaproteobacteria', 'Thermoleophilia',
#        'c__Orbiliomycetes', 'c__Rhizophydiomycetes', 'Pla4_lineage',
#        'p__Rozellomycota_unclassified', 'c__Archaeorhizomycetes',
#        'c__unclassified_Mortierellomycota', 'Holophagae', 'WPS-2_cl',
#        'c__Sordariomycetes', 'c__Mucoromycetes', 'c__Microbotryomycetes',
#        'c__Eurotiomycetes'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                                   OTU  presence_pos  presence_neg
# 0                 Gammaproteobacteria      0.600000      0.139535
# 1       c__unclassified_Rozellomycota      0.142857      0.720930
# 2                         Lineage_IIc      0.885714      0.488372
# 3                c__Sanchytriomycetes      0.000000      0.348837
# 4                 Deltaproteobacteria      0.685714      0.279070
# 5                     Thermoleophilia      0.114286      0.000000
# 6                   c__Orbiliomycetes      0.000000      0.046512
# 7               c__Rhizophydiomycetes      0.028571      0.232558
# 8                        Pla4_lineage      0.000000      0.000000
# 9       p__Rozellomycota_unclassified      0.057143      0.348837
# 10             c__Archaeorhizomycetes      0.000000      0.000000
# 11  c__unclassified_Mortierellomycota      0.000000      0.000000
# 12                         Holophagae      0.028571      0.000000
# 13                           WPS-2_cl      0.000000      0.000000
# 14                 c__Sordariomycetes      0.771429      0.604651
# 15                   c__Mucoromycetes      0.057143      0.023256
# 16              c__Microbotryomycetes      0.028571      0.139535
# 17                  c__Eurotiomycetes      0.771429      0.813953
# FS_Fine tuned Lasso selected Index(['Pseudomonadales', 'o__Leucosporidiales',
#        'Candidatus_Magasanikbacteria', 'o__Sanchytriales', 'Subgroup_5_or',
#        'Solirubrobacterales', 'o__Glomerales', 'Subgroup_6_or',
#        'o__Agaricales', 'Pla4_lineage_or', 'o__Russulales',
#        'o__Dothideomycetes_ord_Incertae_sedis', 'o__Pleosporales',
#        'o__Ophiostomatales', 'o__Tremellales', 'o__Pyxidiophorales',
#        'Subgroup_7', 'p__Chytridiomycota_unclassified', 'o__Mucorales',
#        'o__Eurotiales'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                                       OTU  presence_pos  presence_neg
# 0                         Pseudomonadales      0.600000      0.139535
# 1                     o__Leucosporidiales      0.085714      0.441860
# 2            Candidatus_Magasanikbacteria      0.885714      0.488372
# 3                        o__Sanchytriales      0.000000      0.348837
# 4                           Subgroup_5_or      0.114286      0.000000
# 5                     Solirubrobacterales      0.114286      0.000000
# 6                           o__Glomerales      0.000000      0.046512
# 7                           Subgroup_6_or      0.200000      0.000000
# 8                           o__Agaricales      0.028571      0.232558
# 9                         Pla4_lineage_or      0.000000      0.000000
# 10                          o__Russulales      0.000000      0.069767
# 11  o__Dothideomycetes_ord_Incertae_sedis      0.000000      0.093023
# 12                        o__Pleosporales      0.000000      0.093023
# 13                     o__Ophiostomatales      0.000000      0.000000
# 14                         o__Tremellales      0.000000      0.023256
# 15                     o__Pyxidiophorales      0.000000      0.000000
# 16                             Subgroup_7      0.028571      0.000000
# 17        p__Chytridiomycota_unclassified      0.028571      0.000000
# 18                           o__Mucorales      0.057143      0.023256
# 19                          o__Eurotiales      0.771429      0.813953
# FS_Fine tuned Lasso selected Index(['Actinobacteria', 'p__Monoblepharomycota', 'p__Rozellomycota',
#        'Verrucomicrobia', 'k__Fungi_unclassified', 'Entotheonellaeota',
#        'Nitrospirae', 'p__Basidiomycota'],
#       dtype='object')
# Validation passed: Dimensions are correct.
# Long= 35, short = 43
#                      OTU  presence_pos  presence_neg
# 0         Actinobacteria      0.942857      0.418605
# 1  p__Monoblepharomycota      0.000000      0.348837
# 2       p__Rozellomycota      0.000000      0.325581
# 3        Verrucomicrobia      0.971429      1.000000
# 4  k__Fungi_unclassified      0.171429      0.767442
# 5      Entotheonellaeota      0.000000      0.000000
# 6            Nitrospirae      0.028571      0.000000
# 7       p__Basidiomycota      0.828571      0.813953
